# %%
import main
import os
import subprocess

# %% [markdown]
# # Testing Markov Decision Process

# %% [markdown]
# ### Trial I

# %%
command = ['python', 'main.py', 'minimax', 'random',  "4"]

# Run the command and capture the output
result = subprocess.run(command, capture_output=True, text=True)

# Print the captured output
output = result.stdout

# %%
print(output)
# Out:
# Current state, O to move:
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . O X . . .
# . . . X O . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 2,4
#
# Current state, X to move:
# . . . . . . . .
# . . . . . . . .
# . . . . O . . .
# . . . O O . . .
# . . . X O . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player X to 4,5
#
# Current state, O to move:
# . . . . . . . .
# . . . . . . . .
# . . . . O . . .
# . . . O O . . .
# . . . X X X . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 5,2
#
# Current state, X to move:
# . . . . . . . .
# . . . . . . . .
# . . . . O . . .
# . . . O O . . .
# . . . O X X . .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player X to 1,4
#
# Current state, O to move:
# . . . . . . . .
# . . . . X . . .
# . . . . X . . .
# . . . O X . . .
# . . . O X X . .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 4,6
#
# Current state, X to move:
# . . . . . . . .
# . . . . X . . .
# . . . . X . . .
# . . . O X . . .
# . . . O O O O .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player X to 3,2
#
# Current state, O to move:
# . . . . . . . .
# . . . . X . . .
# . . . . X . . .
# . . X X X . . .
# . . . O O O O .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 0,4
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O . . .
# . . X X O . . .
# . . . O O O O .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player X to 3,5
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O . . .
# . . X X X X . .
# . . . O O O O .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 2,5
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O O . .
# . . X X O O . .
# . . . O O O O .
# . . O . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Player X to 5,5
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O O . .
# . . X X O O . .
# . . . O X O O .
# . . O . . X . .
# . . . . . . . .
# . . . . . . . .
#
# Player O to 6,4
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O O . .
# . . X X O O . .
# . . . O X O O .
# . . O . . O . .
# . . . . O . . .
# . . . . . . . .
#
# Player X to 4,7
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . . . . O O . .
# . . X X O O . .
# . . . O X X X X
# . . O . . O . .
# . . . . O . . .
# . . . . . . . .
#
# Player O to 2,1
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . .
# . . . O X X X X
# . . O . . O . .
# . . . . O . . .
# . . . . . . . .
#
# Player X to 4,2
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . .
# . . X X X X X X
# . . O . . O . .
# . . . . O . . .
# . . . . . . . .
#
# Player O to 3,7
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# . . X X X X O X
# . . O . . O . .
# . . . . O . . .
# . . . . . . . .
#
# Player X to 6,2
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# . . X X X X O X
# . . X . . O . .
# . . X . O . . .
# . . . . . . . .
#
# Player O to 7,2
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# . . O X X X O X
# . . O . . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player X to 4,1
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# . X X X X X O X
# . . O . . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player O to 4,0
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# O O O O O O O X
# . . O . . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player X to 5,3
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . O . . O O . .
# . . O X O O . O
# O O O X O O O X
# . . O X . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player O to 2,2
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . .
# . O O . O O . .
# . . O O O O . O
# O O O X O O O X
# . . O X . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player X to 2,6
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . .
# . O O . O O X .
# . . O O O X . O
# O O O X X O O X
# . . O X . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player O to 1,7
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . O
# . O O . O O O .
# . . O O O O . O
# O O O X O O O X
# . . O O . O . .
# . . O . O . . .
# . . O . . . . .
#
# Player X to 6,3
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . O
# . O O . O O O .
# . . O O O O . O
# O O O X O O O X
# . . O X . O . .
# . . O X O . . .
# . . O . . . . .
#
# Player O to 5,4
#
# Current state, X to move:
# . . . . O . . .
# . . . . O . . O
# . O O . O O O .
# . . O O O O . O
# O O O O O O O X
# . . O O O O . .
# . . O O O . . .
# . . O . . . . .
#
# Player X to 2,7
#
# Current state, O to move:
# . . . . O . . .
# . . . . O . . O
# . O O . O O O X
# . . O O O O . X
# O O O O O O O X
# . . O O O O . .
# . . O O O . . .
# . . O . . . . .
#
# Player O to 5,7
#
# *** Final winner: O ***
# . . . . O . . .
# . . . . O . . O
# . O O . O O O O
# . . O O O O . O
# O O O O O O O O
# . . O O O O . O
# . . O O O . . .
# . . O . . . . .

# %%
output[-10:]
# Out:
# '. . . . \n\n'
